# %%
import sys
print(sys.executable)

import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# C:\Users\KIIT0001\Downloads\brain_tumour_ml_quantum\brainenv310\Scripts\python.exe
# TensorFlow version: 2.13.0

# %%
import os

print(os.listdir("../data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
# ----> 3 print(os.listdir("../data"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data'

# %%
import os
print(os.listdir("data"))
# Out:
# ['test', 'train']

# %%
import os

print("Train folders:", os.listdir("data/train"))
print("Test folders:", os.listdir("data/test"))
# Out:
# Train folders: ['glioma', 'meningioma', 'notumor', 'pituitary']
# Test folders: ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

test_gen = ImageDataGenerator(
    rescale=1./255
)

train_data = train_gen.flow_from_directory(
    "data/train",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

test_data = test_gen.flow_from_directory(
    "data/test",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)
# Out:
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(train_data.num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 11169476 (42.61 MB)
# Trainable params: 11169476 (42.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=5
)
# Out:
# Epoch 1/5
# 179/179 [==============================] - 1012s 6s/step - loss: 0.8810 - accuracy: 0.6222 - val_loss: 0.9130 - val_accuracy: 0.6407
# Epoch 2/5
# 179/179 [==============================] - 762s 4s/step - loss: 0.6618 - accuracy: 0.7307 - val_loss: 0.5845 - val_accuracy: 0.7620
# Epoch 3/5
# 179/179 [==============================] - 571s 3s/step - loss: 0.5693 - accuracy: 0.7768 - val_loss: 0.7270 - val_accuracy: 0.7422
# Epoch 4/5
# 179/179 [==============================] - 332s 2s/step - loss: 0.5177 - accuracy: 0.7938 - val_loss: 0.5124 - val_accuracy: 0.7857
# Epoch 5/5
# 179/179 [==============================] - 420s 2s/step - loss: 0.4535 - accuracy: 0.8221 - val_loss: 0.5641 - val_accuracy: 0.7849

# %%
os.makedirs("models", exist_ok=True)
model.save("models/brain_tumor_model.h5")
# Out:
# C:\Users\KIIT0001\Downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.save("models/brain_tumor_model.keras")

# %%
from tensorflow.keras.models import load_model

test_model = load_model("models/brain_tumor_model.keras")
print("Model loaded successfully ✅")
# Out:
# Model loaded successfully ✅

# %%
pip install qiskit qiskit-aer qiskit-ibm-runtime
# Out:
# Collecting qiskit
#   Using cached qiskit-2.3.0-cp310-abi3-win_amd64.whl (8.6 MB)
# Collecting qiskit-aer
#   Using cached qiskit_aer-0.17.2-cp310-cp310-win_amd64.whl (9.6 MB)
# Collecting qiskit-ibm-runtime
#   Using cached qiskit_ibm_runtime-0.45.0-py3-none-any.whl (1.5 MB)
# Collecting rustworkx>=0.15.0
#   Using cached rustworkx-0.17.1-cp39-abi3-win_amd64.whl (2.1 MB)
# Collecting stevedore>=3.0.0
#   Using cached stevedore-5.6.0-py3-none-any.whl (54 kB)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit) (1.24.3)
# Requirement already satisfied: typing-extensions in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit) (1.15.3)
# Collecting dill>=0.3
#   Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Requirement already satisfied: psutil>=5 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-aer) (7.2.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: packaging in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (26.0)
# Collecting ibm-platform-services>=0.22.6
#   Using cached ibm_platform_services-0.73.1-py3-none-any.whl (378 kB)
# Collecting requests-ntlm>=1.1.0
#   Using cached requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: requests!=2.32.2,>=2.19 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (2.32.5)
# Collecting pydantic>=2.5.0
#   Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.2
#   Using cached ibm_cloud_sdk_core-3.24.2-py3-none-any.whl (75 kB)
# Collecting pydantic-core==2.41.5
#   Using cached pydantic_core-2.41.5-cp310-cp310-win_amd64.whl (2.0 MB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.2
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: six>=1.5 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (2026.1.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: cryptography>=1.3 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (45.0.7)
# Collecting pyspnego>=0.4.0
#   Using cached pyspnego-0.12.0-py3-none-any.whl (130 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Collecting PyJWT<3.0.0,>=2.10.1
#   Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Collecting sspilib>=0.3.0
#   Using cached sspilib-0.5.0-cp310-cp310-win_amd64.whl (563 kB)
# Requirement already satisfied: pycparser in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from cffi>=1.14->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Installing collected packages: typing-inspection, stevedore, sspilib, rustworkx, PyJWT, pydantic-core, dill, annotated-types, qiskit, pydantic, ibm_cloud_sdk_core, qiskit-aer, pyspnego, ibm-platform-services, requests-ntlm, qiskit-ibm-runtime
# Successfully installed PyJWT-2.10.1 annotated-types-0.7.0 dill-0.4.1 ibm-platform-services-0.73.1 ibm_cloud_sdk_core-3.24.2 pydantic-2.12.5 pydantic-core-2.41.5 pyspnego-0.12.0 qiskit-2.3.0 qiskit-aer-0.17.2 qiskit-ibm-runtime-0.45.0 requests-ntlm-1.3.0 rustworkx-0.17.1 sspilib-0.5.0 stevedore-5.6.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\KIIT0001\Downloads\brain_tumour_ml_quantum\brainenv310\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
python -c "import qiskit; print(qiskit.__version__)"
# Out:
#   Cell In[12], line 1
#     python -c "import qiskit; print(qiskit.__version__)"
#               ^
# SyntaxError: invalid syntax

# %%
model.input_shape
# Out:
# Running cells with 'Python 3.10.5' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/KIIT0001/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined
