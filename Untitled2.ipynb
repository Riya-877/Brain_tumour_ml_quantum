# %%
import qiskit
print(qiskit.__version__)
# Out:
# 2.3.0

# %%
import qiskit
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# Create circuit
qc = QuantumCircuit(3, 3)
qc.h(0)
qc.cx(0, 1)
qc.cx(1, 2)
qc.measure([0,1,2], [0,1,2])

# Simulator
simulator = AerSimulator()
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()

counts
# Out:
# {'000': 525, '111': 499}

# %%
pip install qiskit-ibm-runtime
# Out:
# Requirement already satisfied: qiskit-ibm-runtime in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (0.45.0)
# Requirement already satisfied: numpy>=1.13 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (1.24.3)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (0.73.1)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: packaging in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (26.0)
# Requirement already satisfied: qiskit>=2.0.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (2.3.0)
# Requirement already satisfied: pydantic>=2.5.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (2.12.5)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: requests!=2.32.2,>=2.19 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit-ibm-runtime) (2.32.5)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.2 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit>=2.0.0->qiskit-ibm-runtime) (5.6.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit>=2.0.0->qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: dill>=0.3 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit>=2.0.0->qiskit-ibm-runtime) (0.4.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from qiskit>=2.0.0->qiskit-ibm-runtime) (1.15.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (2026.1.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: cryptography>=1.3 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (45.0.7)
# Requirement already satisfied: pyspnego>=0.4.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.10.1)
# Requirement already satisfied: sspilib>=0.3.0 in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.5.0)
# Requirement already satisfied: pycparser in c:\users\kiit0001\downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages (from cffi>=1.14->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\KIIT0001\Downloads\brain_tumour_ml_quantum\brainenv310\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.save_account(
    channel="ibm_quantum",
    token="PASTE_YOUR_IBM_API_KEY_HERE",
    overwrite=True
)
# Out:
# ---------------------------------------------------------------------------
# InvalidAccountError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 from qiskit_ibm_runtime import QiskitRuntimeService
# ----> 3 QiskitRuntimeService.save_account(
#       4     channel="ibm_quantum",
#       5     token="PASTE_YOUR_IBM_API_KEY_HERE",
#       6     overwrite=True
#       7 )
#
# File ~\Downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:840, in QiskitRuntimeService.save_account(token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#     789 @staticmethod
#     790 def save_account(
#     791     token: str | None = None,
#    (...)
#     804     tags: list[str] | None = None,
#     805 ) -> None:
#     806     """Save the account to disk for future use.
#     807
#     808     Args:
#    (...)
#     837
#     838     """
# --> 840     AccountManager.save(
#     841         token=token,
#     842         url=url,
#     843         instance=instance,
#     844         channel=channel,
#     845         filename=filename,
#     846         name=name,
#     847         proxies=ProxyConfiguration(**proxies) if proxies else None,
#     848         verify=verify,
#     849         overwrite=overwrite,
#     850         set_as_default=set_as_default,
#     851         private_endpoint=private_endpoint,
#     852         region=region,
#     853         plans_preference=plans_preference,
#     854         tags=tags,  # type: ignore[arg-type]
#     855     )
#
# File ~\Downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages\qiskit_ibm_runtime\accounts\management.py:67, in AccountManager.save(cls, token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#      64 filename = filename if filename else _DEFAULT_ACCOUNT_CONFIG_JSON_FILE
#      65 filename = os.path.expanduser(filename)
# ---> 67 config = Account.create_account(
#      68     channel=channel,  # type: ignore[arg-type]
#      69     token=token,  # type: ignore[arg-type]
#      70     url=url,
#      71     instance=instance,
#      72     proxies=proxies,
#      73     verify=verify,
#      74     private_endpoint=private_endpoint,
#      75     region=region,
#      76     plans_preference=plans_preference,
#      77     tags=tags,  # type: ignore[arg-type]
#      78 )
#      79 return save_config(
#      80     filename=filename,
#      81     name=name,
#    (...)
#      86     set_as_default=set_as_default,
#      87 )
#
# File ~\Downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages\qiskit_ibm_runtime\accounts\account.py:139, in Account.create_account(cls, channel, token, url, instance, proxies, verify, private_endpoint, region, plans_preference, tags)
#     126     return CloudAccount(
#     127         url=url,
#     128         token=token,
#    (...)
#     136         tags=tags,  # type: ignore[arg-type]
#     137     )
#     138 else:
# --> 139     raise InvalidAccountError(
#     140         f"Invalid `channel` value. Expected one of "
#     141         f"{['ibm_cloud', 'ibm_quantum_platform']}, got '{channel}'."
#     142     )
#
# InvalidAccountError: "Invalid `channel` value. Expected one of ['ibm_cloud', 'ibm_quantum_platform'], got 'ibm_quantum'."

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.save_account(
    channel="ibm_quantum",
    token="0oEsRr6Vojw0ZFY7611nHrBRRpwCl7_Cxkg5zuE-U_z2",
    overwrite=True
)
# Out:
# ---------------------------------------------------------------------------
# InvalidAccountError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from qiskit_ibm_runtime import QiskitRuntimeService
# ----> 3 QiskitRuntimeService.save_account(
#       4     channel="ibm_quantum",
#       5     token="0oEsRr6Vojw0ZFY7611nHrBRRpwCl7_Cxkg5zuE-U_z2",
#       6     overwrite=True
#       7 )
#
# File ~\Downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:840, in QiskitRuntimeService.save_account(token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#     789 @staticmethod
#     790 def save_account(
#     791     token: str | None = None,
#    (...)
#     804     tags: list[str] | None = None,
#     805 ) -> None:
#     806     """Save the account to disk for future use.
#     807
#     808     Args:
#    (...)
#     837
#     838     """
# --> 840     AccountManager.save(
#     841         token=token,
#     842         url=url,
#     843         instance=instance,
#     844         channel=channel,
#     845         filename=filename,
#     846         name=name,
#     847         proxies=ProxyConfiguration(**proxies) if proxies else None,
#     848         verify=verify,
#     849         overwrite=overwrite,
#     850         set_as_default=set_as_default,
#     851         private_endpoint=private_endpoint,
#     852         region=region,
#     853         plans_preference=plans_preference,
#     854         tags=tags,  # type: ignore[arg-type]
#     855     )
#
# File ~\Downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages\qiskit_ibm_runtime\accounts\management.py:67, in AccountManager.save(cls, token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#      64 filename = filename if filename else _DEFAULT_ACCOUNT_CONFIG_JSON_FILE
#      65 filename = os.path.expanduser(filename)
# ---> 67 config = Account.create_account(
#      68     channel=channel,  # type: ignore[arg-type]
#      69     token=token,  # type: ignore[arg-type]
#      70     url=url,
#      71     instance=instance,
#      72     proxies=proxies,
#      73     verify=verify,
#      74     private_endpoint=private_endpoint,
#      75     region=region,
#      76     plans_preference=plans_preference,
#      77     tags=tags,  # type: ignore[arg-type]
#      78 )
#      79 return save_config(
#      80     filename=filename,
#      81     name=name,
#    (...)
#      86     set_as_default=set_as_default,
#      87 )
#
# File ~\Downloads\brain_tumour_ml_quantum\brainenv310\lib\site-packages\qiskit_ibm_runtime\accounts\account.py:139, in Account.create_account(cls, channel, token, url, instance, proxies, verify, private_endpoint, region, plans_preference, tags)
#     126     return CloudAccount(
#     127         url=url,
#     128         token=token,
#    (...)
#     136         tags=tags,  # type: ignore[arg-type]
#     137     )
#     138 else:
# --> 139     raise InvalidAccountError(
#     140         f"Invalid `channel` value. Expected one of "
#     141         f"{['ibm_cloud', 'ibm_quantum_platform']}, got '{channel}'."
#     142     )
#
# InvalidAccountError: "Invalid `channel` value. Expected one of ['ibm_cloud', 'ibm_quantum_platform'], got 'ibm_quantum'."

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.save_account(
    channel="ibm_quantum_platform",
    token="0oEsRr6Vojw0ZFY7611nHrBRRpwCl7_Cxkg5zuE-U_z2",
    overwrite=True
)

# %%
service = QiskitRuntimeService()
service.backends()
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-01-28 10:28:41,847: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2026-01-28 10:28:41,853: Loading instance: open-instance, plan: open
# [<IBMBackend('ibm_fez')>,
#  <IBMBackend('ibm_torino')>,
#  <IBMBackend('ibm_marrakesh')>]

# %%
print(qc.draw())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(qc.draw())
#
# NameError: name 'qc' is not defined
